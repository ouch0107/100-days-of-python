# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("resource/cat.jpeg")

# %%
img.shape
# Out:
# (201, 250, 3)

# %%
plt.imshow(img[:10,:10])

# %%
plt.imshow(img)

# %%
test_pixel = img[2:4,2:4]
test_pixel
# Out:
# array([[[18, 38, 71],
#         [22, 43, 74]],
#
#        [[22, 42, 75],
#         [25, 46, 77]]], dtype=uint8)

# %%
test_pixel.mean(axis=0)
# Out:
# array([[20. , 40. , 73. ],
#        [23.5, 44.5, 75.5]])

# %%
pixel_mean = test_pixel.mean(axis=1).mean(axis=0)
pixel_mean
# Out:
# array([21.75, 42.25, 74.25])

# %%
plt.subplot(2,2,1)
plt.imshow(img[:100,:125])

plt.subplot(2,2,2)
plt.imshow(img[:100,125:250])

plt.subplot(2,2,3)
plt.imshow(img[100:200,:125])

plt.subplot(2,2,4)
plt.imshow(img[100:200,125:250])

# %%
img.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : False
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
img.setflags(write=1)

# %%
for i in range(25):
    for j in range(20):
        img_pixel_mean = img[j*10:(j+1)*10, i*10:(i+1)*10].mean(axis=1).mean(axis=0)
        img[j*10:(j+1)*10, i*10:(i+1)*10] = img_pixel_mean

# %%
plt.imshow(img)
